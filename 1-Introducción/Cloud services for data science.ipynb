# %% [markdown]
# # Cloud services for data science

# %% [markdown]
# 1. Cloud service providers: Amazon Web Services, Google Cloud Services, Microsoft Azure
# 2. My own cloud environment for Data Science
