# %%
# %matplotlib inline

# %% [markdown]
# # Pandas
# <!-- requirement: img/Data_Frame_Data_Series.png -->
# <!-- requirement: small_data/fha_by_tract.csv -->
# <!-- requirement: small_data/2013_Gaz_tracts_national.tsv -->
#
# Pandas is Python's answer to R.  It's a good tool for small(ish) data analysis -- i.e. when everything fits into memory.
#
# The basic new "noun" in pandas is the **data frame**.

# %% [markdown]
# ## Nouns (objects) in Pandas
#
# ### Data Frames
#
# Like a table, with rows and columns (e.g. as in SQL).  Except:
#   - The rows can be indexed by something interesting (there is special support for labels like categorical and timeseries data).  This is especially useful when you have timeseries data with potentially missing data points.
#   - Cells can store Python objects. Like in SQL, columns are type homogeneous.
#   - Instead of "NULL", the name for a non-existent value is "NA".  Unlike R, Python's data frames only support NAs in columns of some data types (basically: floating point numbers and 'objects') -- but this is mostly a non-issue (because it will "up-cast" integers to float64, etc.)
#
# ### Data Series:
#
# These are named columns of a DataFrame (more correctly, a dataframe is a dictionary of Series).  The entries of the series have homogenous type.
#
# <img src="img/4-pandas/Data_Frame_Data_Series.png">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# a data frame
df1 = pd.DataFrame({
    'number': [1, 2, 3],
    'animal': ['cat', 'dog', 'mouse']
})

df1
# Out:
#   animal  number
# 0    cat       1
# 1    dog       2
# 2  mouse       3

# %%
# select the animal series from the dataframe using the different notations
df1['animal']
# Out:
# 0      cat
# 1      dog
# 2    mouse
# Name: animal, dtype: object

# %%
df1.animal
# Out:
# 0      cat
# 1      dog
# 2    mouse
# Name: animal, dtype: object

# %%
# show the types of the dataframe columns
df1.dtypes
# Out:
# animal    object
# number     int64
# dtype: object

# %%
df1['number'] = df1['number'].astype(float)

# %%
df1
# Out:
#   animal  number
# 0    cat     1.0
# 1    dog     2.0
# 2  mouse     3.0

# %%
# the same data frame
df2 = pd.DataFrame([
    ('cat', 1),
    ('dog', 3),
    ('mouse', 3),
], columns=['animal', 'number'])

np.all(df1 == df2)
# Out:
# False

# %% [markdown]
# ## Verbs (operations) in Pandas
#
# Pandas provides a "batteries-included" basic data analysis:
#   - **Loading data:** `read_csv`, `read_table`, `read_sql`, and `read_html`
#   - **Selection, filtering, and aggregation** (i.e. SQL-type operations): There's a special syntax for `SELECT`ing.  There's the `merge` method for `JOIN`ing.  There's also an easy syntax for what in SQL is a mouthful: Creating a new column whose value is computed from another column -- with the bonus that now the computations can use the full power of Python (though it might be faster if it didn't).
#   - **"Pivot table" style aggregation:** If you're an Excel cognoscenti, you may appreciate this.
#   - **NA handling:** Like R's data frames, there is good support for transforming NA values with default values / averaging tricks / etc.
#   - **Basic statistics:** e.g. `mean`, `median`, `max`, `min`, and the convenient `describe`.
#   - **Plugging into more advanced analytics:** Okay, this isn't batteries included.  But still, it plays reasonably with `sklearn`.
#   - **Visualization:** For instance `plot` and `hist`.
#
# We'll go through a little on all of these in the context of an example.
#
# We're going to explore a dataset of mortgage insurance issued by the Federal Housing Authority (FHA).  The data is broken down by census tract and tells us how big of a player the FHA is in each tract (how many homes etc.).

# %% [markdown]
# ## Loading data (and basic statistics / visualization)

# %%
names =["State_Code", "County_Code", "Census_Tract_Number",
        "NUM_ALL", "NUM_FHA", "PCT_NUM_FHA", "AMT_ALL",
        "AMT_FHA", "PCT_AMT_FHA"]

df = pd.read_csv('fha_by_tract.csv', names=names)  # Loading a CSV file, without a header (so we have to provide field names)

df.head()
# Out:
#    State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 0         8.0         75.0                  NaN        1        1
# 1        28.0         49.0               103.01        1        1
# 2        40.0          3.0                  NaN        1        1
# 3        39.0        113.0               603.00        3        3
# 4        12.0        105.0               124.04        2        2
#
#    PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA
# 0        100.0      258      258        100.0
# 1        100.0       71       71        100.0
# 2        100.0      215      215        100.0
# 3        100.0      206      206        100.0
# 4        100.0      303      303        100.0

# %%
names =["StateCode", "County_Code", "Census_Tract_Number",
        "NUM_ALL", "NUM_FHA", "PCT_NUM_FHA", "AMT_ALL",
        "AMT_FHA", "PCT_AMT_FHA"]

df.columns = names

# %%
df = df.rename(columns={"StateCode":"State_Code"})

# %%
df.head()
# Out:
#    State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 0         8.0         75.0                  NaN        1        1
# 1        28.0         49.0               103.01        1        1
# 2        40.0          3.0                  NaN        1        1
# 3        39.0        113.0               603.00        3        3
# 4        12.0        105.0               124.04        2        2
#
#    PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA
# 0        100.0      258      258        100.0
# 1        100.0       71       71        100.0
# 2        100.0      215      215        100.0
# 3        100.0      206      206        100.0
# 4        100.0      303      303        100.0

# %%
## Create a new column from a combination of the others 'Census_Tract_Number', 'County_Code'] and 'State_Code'
df['GEOID'] = df['Census_Tract_Number']*100 + 10**6 * df['County_Code'] \
    + 10**9 * df['State_Code']   # A computed field!
df.head()
# Out:
#    State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 0         8.0         75.0                  NaN        1        1
# 1        28.0         49.0               103.01        1        1
# 2        40.0          3.0                  NaN        1        1
# 3        39.0        113.0               603.00        3        3
# 4        12.0        105.0               124.04        2        2
#
#    PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA         GEOID
# 0        100.0      258      258        100.0           NaN
# 1        100.0       71       71        100.0  2.804901e+10
# 2        100.0      215      215        100.0           NaN
# 3        100.0      206      206        100.0  3.911306e+10
# 4        100.0      303      303        100.0  1.210501e+10

# %% [markdown]
# To drop a column:

# %%
column_to_drop = 'GEOID'
df.drop(column_to_drop, axis = 1).head()
# Out:
#    State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 0         8.0         75.0                  NaN        1        1
# 1        28.0         49.0               103.01        1        1
# 2        40.0          3.0                  NaN        1        1
# 3        39.0        113.0               603.00        3        3
# 4        12.0        105.0               124.04        2        2
#
#    PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA
# 0        100.0      258      258        100.0
# 1        100.0       71       71        100.0
# 2        100.0      215      215        100.0
# 3        100.0      206      206        100.0
# 4        100.0      303      303        100.0

# %% [markdown]
# Most operations produce copies (unless `inplace=True` is specified).  The `df` object still has the GEOID column.

# %%
column_to_drop in df.columns
# Out:
# True

# %%
# To use inplace=True is not advised. It is better to assign the transformed dataframe to a new variable

df_new = df.drop(column_to_drop, axis = 1)

print(column_to_drop in df.columns)

print(column_to_drop in df_new.columns)
# Out:
# True
# False

# %% [markdown]
# Rows can also be dropped.  Note that the indices do not reset.  The index is associated with the row, not with the order.

# %%
df.drop(0, axis=0).head()
# Out:
#    State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 1        28.0         49.0               103.01        1        1
# 2        40.0          3.0                  NaN        1        1
# 3        39.0        113.0               603.00        3        3
# 4        12.0        105.0               124.04        2        2
# 5        12.0         86.0              9808.00        1        1
#
#    PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA         GEOID
# 1        100.0       71       71        100.0  2.804901e+10
# 2        100.0      215      215        100.0           NaN
# 3        100.0      206      206        100.0  3.911306e+10
# 4        100.0      303      303        100.0  1.210501e+10
# 5        100.0      188      188        100.0  1.208698e+10

# %% [markdown]
# By default, rows are indexed by their position.  However, any column can be made into an index:

# %%
df.set_index('State_Code').head(6)
# Out:
#             County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  PCT_NUM_FHA  \
# State_Code
# 8.0                75.0                  NaN        1        1        100.0
# 28.0               49.0               103.01        1        1        100.0
# 40.0                3.0                  NaN        1        1        100.0
# 39.0              113.0               603.00        3        3        100.0
# 12.0              105.0               124.04        2        2        100.0
# 12.0               86.0              9808.00        1        1        100.0
#
#             AMT_ALL  AMT_FHA  PCT_AMT_FHA         GEOID
# State_Code
# 8.0             258      258        100.0           NaN
# 28.0             71       71        100.0  2.804901e+10
# 40.0            215      215        100.0           NaN
# 39.0            206      206        100.0  3.911306e+10
# 12.0            303      303        100.0  1.210501e+10
# 12.0            188      188        100.0  1.208698e+10

# %% [markdown]
# Multiple levels of indexing is possible:

# %%
df.set_index(['State_Code', 'County_Code']).head(6)
# Out:
#                         Census_Tract_Number  NUM_ALL  NUM_FHA  PCT_NUM_FHA  \
# State_Code County_Code
# 8.0        75.0                         NaN        1        1        100.0
# 28.0       49.0                      103.01        1        1        100.0
# 40.0       3.0                          NaN        1        1        100.0
# 39.0       113.0                     603.00        3        3        100.0
# 12.0       105.0                     124.04        2        2        100.0
#            86.0                     9808.00        1        1        100.0
#
#                         AMT_ALL  AMT_FHA  PCT_AMT_FHA         GEOID
# State_Code County_Code
# 8.0        75.0             258      258        100.0           NaN
# 28.0       49.0              71       71        100.0  2.804901e+10
# 40.0       3.0              215      215        100.0           NaN
# 39.0       113.0            206      206        100.0  3.911306e+10
# 12.0       105.0            303      303        100.0  1.210501e+10
#            86.0             188      188        100.0  1.208698e+10

# %% [markdown]
# An index can be turned back into a column:

# %%
df.set_index('State_Code').reset_index().head()
# Out:
#    State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 0         8.0         75.0                  NaN        1        1
# 1        28.0         49.0               103.01        1        1
# 2        40.0          3.0                  NaN        1        1
# 3        39.0        113.0               603.00        3        3
# 4        12.0        105.0               124.04        2        2
#
#    PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA         GEOID
# 0        100.0      258      258        100.0           NaN
# 1        100.0       71       71        100.0  2.804901e+10
# 2        100.0      215      215        100.0           NaN
# 3        100.0      206      206        100.0  3.911306e+10
# 4        100.0      303      303        100.0  1.210501e+10

# %%
print("Percentage of mortages in each census tract insured by FHA")
df['PCT_AMT_FHA'].describe()
# Out:
# Percentage of mortages in each census tract insured by FHA
# count    72035.000000
# mean        29.703179
# std         24.037779
# min          0.000000
# 25%         10.780800
# 50%         24.753900
# 75%         44.207550
# max        100.000000
# Name: PCT_AMT_FHA, dtype: float64

# %%
# Apply describe to the entire dataframe
df.describe()
# Out:
#          State_Code   County_Code  Census_Tract_Number       NUM_ALL  \
# count  72034.000000  71984.000000         71040.000000  72035.000000
# mean      28.322528     85.612636          2534.598023     36.970389
# std       16.459507     98.672445          3451.173223     53.975403
# min        1.000000      1.000000             1.000000      1.000000
# 25%       13.000000     29.000000           103.020000     13.000000
# 50%       28.000000     63.000000           442.010000     27.000000
# 75%       42.000000    109.000000          4503.012500     48.000000
# max       72.000000    840.000000          9922.010000   9477.000000
#
#             NUM_FHA   PCT_NUM_FHA       AMT_ALL        AMT_FHA   PCT_AMT_FHA  \
# count  72035.000000  72035.000000  7.203500e+04   72035.000000  72035.000000
# mean       9.741667     28.566878  7.886092e+03    1689.278851     29.703179
# std       15.187832     22.404545  1.302542e+04    2800.346300     24.037779
# min        0.000000      0.000000  2.000000e+00       0.000000      0.000000
# 25%        2.000000     11.111100  1.551000e+03     281.000000     10.780800
# 50%        6.000000     25.000000  4.168000e+03     932.000000     24.753900
# 75%       13.000000     41.935500  9.668000e+03    2197.000000     44.207550
# max     1932.000000    100.000000  1.575871e+06  331515.000000    100.000000
#
#               GEOID
# count  7.104000e+04
# mean   2.837319e+10
# std    1.648784e+10
# min    1.001020e+09
# 25%    1.301596e+10
# 50%    2.804900e+10
# 75%    4.200348e+10
# max    7.215375e+10

# %%
# %matplotlib inline

# %%
# plot an histogram of the column PCT_AMT_FHA
df['PCT_AMT_FHA'].plot(kind='hist', bins=100)

# %% [markdown]
# The above distribution looks skewed, so let's look at its logarithm.

# %%
df['LOG_AMT_ALL'] = np.log1p(df['AMT_ALL'])  # Create a new column to examine
print(df['LOG_AMT_ALL'].describe())

df['AMT_ALL'].apply(np.log1p).hist(bins=500)  # Or apply a function to each element
# Out:
# count    72035.000000
# mean         8.170124
# std          1.429644
# min          1.098612
# 25%          7.347300
# 50%          8.335431
# 75%          9.176680
# max         14.270319
# Name: LOG_AMT_ALL, dtype: float64

# %% [markdown]
# ## Indexing data frames
#
# Indexing by a column name yields a data series.

# %%
df['State_Code'].head()
# Out:
# 0     8.0
# 1    28.0
# 2    40.0
# 3    39.0
# 4    12.0
# Name: State_Code, dtype: float64

# %% [markdown]
# Indexing by a list of column names gives another data frame.

# %%
df[['State_Code', 'County_Code']].head()
# Out:
#    State_Code  County_Code
# 0         8.0         75.0
# 1        28.0         49.0
# 2        40.0          3.0
# 3        39.0        113.0
# 4        12.0        105.0

# %% [markdown]
# **Question:** What will this return?

# %%
type(df[['State_Code']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['State_Code']].head()
# Out:
#    State_Code
# 0         8.0
# 1        28.0
# 2        40.0
# 3        39.0
# 4        12.0

# %% [markdown]
# A data frame is an iterator that yields the column names:

# %%
[col for col in df]
# Out:
# ['State_Code',
#  'County_Code',
#  'Census_Tract_Number',
#  'NUM_ALL',
#  'NUM_FHA',
#  'PCT_NUM_FHA',
#  'AMT_ALL',
#  'AMT_FHA',
#  'PCT_AMT_FHA',
#  'GEOID',
#  'LOG_AMT_ALL']

# %% [markdown]
# To select specific rows, you can try:

# %%
df[:3]
# Out:
#    State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 0         8.0         75.0                  NaN        1        1
# 1        28.0         49.0               103.01        1        1
# 2        40.0          3.0                  NaN        1        1
#
#    PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA         GEOID  LOG_AMT_ALL
# 0        100.0      258      258        100.0           NaN     5.556828
# 1        100.0       71       71        100.0  2.804901e+10     4.276666
# 2        100.0      215      215        100.0           NaN     5.375278

# %% [markdown]
# To index a particular element of the frame, use the `.loc` attribute.  It takes index and column names.

# %%
df.loc[:3]
# Out:
#    State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 0         8.0         75.0                  NaN        1        1
# 1        28.0         49.0               103.01        1        1
# 2        40.0          3.0                  NaN        1        1
# 3        39.0        113.0               603.00        3        3
#
#    PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA         GEOID  LOG_AMT_ALL
# 0        100.0      258      258        100.0           NaN     5.556828
# 1        100.0       71       71        100.0  2.804901e+10     4.276666
# 2        100.0      215      215        100.0           NaN     5.375278
# 3        100.0      206      206        100.0  3.911306e+10     5.332719

# %%
df.loc[3, 'State_Code']
# Out:
# 39.0

# %% [markdown]
# Both can be sliced.  Unusually for Python, both endpoints are included in the slice.

# %%
df.loc[0:3, ['State_Code','Census_Tract_Number']]
# Out:
#    State_Code  Census_Tract_Number
# 0         8.0                  NaN
# 1        28.0               103.01
# 2        40.0                  NaN
# 3        39.0               603.00

# %% [markdown]
# Position-based indexing is available in the `.iloc` attribute.

# %%
df.iloc[3, 0:3]
# Out:
# State_Code              39.0
# County_Code            113.0
# Census_Tract_Number    603.0
# Name: 3, dtype: float64

# %%
pd.__version__
# Out:
# '0.20.3'

# %% [markdown]
# The usual slicing convention is used for `.iloc`.

# %%
df.iloc[0:3, 0:3]
# Out:
#    State_Code  County_Code  Census_Tract_Number
# 0         8.0         75.0                  NaN
# 1        28.0         49.0               103.01
# 2        40.0          3.0                  NaN

# %% [markdown]
# ## Filtering data
#
# Now the `df[...]` notation is very flexible:
#   - It accepts column names (strings and lists of strings);
#   - It accepts column numbers (so long as there is no ambiguity with column names);
#   - It accepts _binary data series!_
#
# This means that you can write
# ```python
#
#  df[ df['column_name2'] == 'MD' & ( df['column_name1']==5 | df['column_name1']==6 ) ]
# ```
# for what you would write in SQL as
#
# ```sql
# SELECT * FROM df
# WHERE column_name2="MD" AND (column_name1=5 OR column_name1=6)
# ```
# Boolean operators on a data frame return a data series of bools.

# %%
(df['State_Code'] == 1).head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: State_Code, dtype: bool

# %% [markdown]
# These can be combined with the (bitwise) boolean operators.  Note that, due to operator precedence, you want to wrap the individual comparisons in parentheses.

# %%
((df['State_Code'] == 1) & (df['Census_Tract_Number'] == 9613)).head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# Data frames accept indexing by boolean series.

# %%
df[df['State_Code'] == 5][['State_Code', 'County_Code']].head()
# Out:
#       State_Code  County_Code
# 77           5.0        119.0
# 186          5.0         69.0
# 904          5.0        119.0
# 986          5.0        119.0
# 1252         5.0        119.0

# %% [markdown]
# **Note:** select rows by binary data series only if they share the same data index!
#
# **Exercise:**
# 1. Plot the histogram of percentages for different states in the same graph to compare them.
# 2. Notice that there is a spike at 100%.  This means that the FHA has insured 100% of the houses in that census tract.  See what happens to the histogram when we restrict it to the case where the total number of loans is non-negligible.

# %% [markdown]
# ## Joining data
#
# The analogue of a
#
# >
#     SELECT *
#         FROM df1
#         INNER JOIN df2
#         ON df1.field_name=df2.field_name;
#
# is
#
#     df_joined = df1.merge(df2, on='field_name')
#
# You can also do left / right / outer joins, mix-and-match column names, etc.  For that consult the Pandas documentation. (The example below will do a left join.)
#
# Of course, just looking at the distribution of insurance by census tract isn't interesting unless we know more about the census tract.

# %%
df.head()
# Out:
#    State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 0         8.0         75.0                  NaN        1        1
# 1        28.0         49.0               103.01        1        1
# 2        40.0          3.0                  NaN        1        1
# 3        39.0        113.0               603.00        3        3
# 4        12.0        105.0               124.04        2        2
#
#    PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA         GEOID  LOG_AMT_ALL
# 0        100.0      258      258        100.0           NaN     5.556828
# 1        100.0       71       71        100.0  2.804901e+10     4.276666
# 2        100.0      215      215        100.0           NaN     5.375278
# 3        100.0      206      206        100.0  3.911306e+10     5.332719
# 4        100.0      303      303        100.0  1.210501e+10     5.717028

# %%
# The first row is the column names, so we don't have to specify those
df_geo = pd.read_csv('2013_Gaz_tracts_national.tsv', sep='\t')
df_geo.head()
# Out:
#   USPS       GEOID     ALAND  AWATER  ALAND_SQMI  AWATER_SQMI   INTPTLAT  \
# 0   AL  1001020100   9809939   36312       3.788        0.014  32.481794
# 1   AL  1001020200   3340498    5846       1.290        0.002  32.475758
# 2   AL  1001020300   5349274    9054       2.065        0.003  32.474024
# 3   AL  1001020400   6382705   16244       2.464        0.006  32.471030
# 4   AL  1001020500  11397734   48412       4.401        0.019  32.458916
#
#    INTPTLONG
# 0                                         -86.490249
# 1                                         -86.472468
# 2                                         -86.459703
# 3                                         -86.444835
# 4                                         -86.421817

# %%
df_joined = df.merge(df_geo, on='GEOID', how='left')
df_joined.head()
# Out:
#    State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 0         8.0         75.0                  NaN        1        1
# 1        28.0         49.0               103.01        1        1
# 2        40.0          3.0                  NaN        1        1
# 3        39.0        113.0               603.00        3        3
# 4        12.0        105.0               124.04        2        2
#
#    PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA        GEOID  LOG_AMT_ALL USPS  \
# 0        100.0      258      258        100.0          NaN     5.556828  NaN
# 1        100.0       71       71        100.0   2.8049e+10     4.276666   MS
# 2        100.0      215      215        100.0          NaN     5.375278  NaN
# 3        100.0      206      206        100.0  3.91131e+10     5.332719   OH
# 4        100.0      303      303        100.0   1.2105e+10     5.717028   FL
#
#          ALAND     AWATER  ALAND_SQMI  AWATER_SQMI   INTPTLAT  \
# 0          NaN        NaN         NaN          NaN        NaN
# 1    8162270.0    22648.0       3.151        0.009  32.365904
# 2          NaN        NaN         NaN          NaN        NaN
# 3    5382347.0        0.0       2.078        0.000  39.729932
# 4  105120002.0  1800522.0      40.587        0.695  28.224489
#
#    INTPTLONG
# 0                                                NaN
# 1                                         -90.262379
# 2                                                NaN
# 3                                         -84.268323
# 4                                         -81.739745

# %% [markdown]
# ## Aggregating data
#
# The analog of SQL's `GROUP BY` is
#
#     grouped = df.groupby(['field_name1', ...])...
#
# The above is analogous to
# >
#     SELECT mean(df.value1), std(df.value2)
#         FROM df
#         GROUP BY df.field_name1, ...
#
# Pandas is somewhat more flexible in how you can use grouping, not requiring you to specify an aggregation function up front.  The `.groupby()` method that can later be aggregated.

# %%
usps_groups = df_joined.groupby('USPS')
usps_groups.

# %% [markdown]
# The reason Pandas doesn't require you to specify an aggregation function up front is because the groupby method by itself does little work. It returns a `DataFrameGroupBy` datatype that contains a dictionary of group keys to lists of row numbers.

# %%
print(type(usps_groups.groups))
usps_groups.groups['AK'][:5]
# Out:
# <class 'dict'>
# Int64Index([91, 298, 536, 2528, 4146], dtype='int64')

# %%
usps_groups.groups.keys()
# Out:
# dict_keys(['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'PR', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY'])

# %% [markdown]
# I can retrieve the group of data associated with one key:

# %%
usps_groups.get_group('AK')[:5]
# Out:
#       State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 91           2.0         50.0                  3.0        1        1
# 298          2.0         20.0                  4.0        1        1
# 536          2.0        122.0                  1.0        1        1
# 2528         2.0        185.0                  1.0       11        8
# 4146         2.0        122.0                 12.0        3        2
#
#       PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA      GEOID  LOG_AMT_ALL USPS  \
# 91       100.0000      121      121     100.0000   2.05e+09     4.804021   AK
# 298      100.0000      192      192     100.0000   2.02e+09     5.262690   AK
# 536      100.0000       39       39     100.0000  2.122e+09     3.688879   AK
# 2528      72.7273     1958     1604      81.9203  2.185e+09     7.580189   AK
# 4146      66.6667      530      392      73.9623  2.122e+09     6.274762   AK
#
#              ALAND        AWATER  ALAND_SQMI  AWATER_SQMI   INTPTLAT  \
# 91    4.930719e+10  6.258804e+08   19037.615      241.654  61.468804
# 298   5.336808e+07  2.393787e+07      20.606        9.242  61.266668
# 536   1.982658e+10  1.006239e+10    7655.087     3885.112  60.123779
# 2528  2.532416e+08  3.781985e+08      97.777      146.023  71.287938
# 4146  2.498757e+09  4.721135e+09     964.775     1822.840  59.356474
#
#       INTPTLONG
# 91                                          -156.692206
# 298                                         -149.830858
# 536                                         -152.841141
# 2528                                        -156.685618
# 4146                                        -151.771450

# %% [markdown]
# Observe that this is the same as:

# %%
df_joined.iloc[usps_groups.groups['AK'][:5]]
# Out:
#       State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 91           2.0         50.0                  3.0        1        1
# 298          2.0         20.0                  4.0        1        1
# 536          2.0        122.0                  1.0        1        1
# 2528         2.0        185.0                  1.0       11        8
# 4146         2.0        122.0                 12.0        3        2
#
#       PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA      GEOID  LOG_AMT_ALL USPS  \
# 91       100.0000      121      121     100.0000   2.05e+09     4.804021   AK
# 298      100.0000      192      192     100.0000   2.02e+09     5.262690   AK
# 536      100.0000       39       39     100.0000  2.122e+09     3.688879   AK
# 2528      72.7273     1958     1604      81.9203  2.185e+09     7.580189   AK
# 4146      66.6667      530      392      73.9623  2.122e+09     6.274762   AK
#
#              ALAND        AWATER  ALAND_SQMI  AWATER_SQMI   INTPTLAT  \
# 91    4.930719e+10  6.258804e+08   19037.615      241.654  61.468804
# 298   5.336808e+07  2.393787e+07      20.606        9.242  61.266668
# 536   1.982658e+10  1.006239e+10    7655.087     3885.112  60.123779
# 2528  2.532416e+08  3.781985e+08      97.777      146.023  71.287938
# 4146  2.498757e+09  4.721135e+09     964.775     1822.840  59.356474
#
#       INTPTLONG
# 91                                          -156.692206
# 298                                         -149.830858
# 536                                         -152.841141
# 2528                                        -156.685618
# 4146                                        -151.771450

# %%
usps_groups.mean().head()  # Takes the mean of the rows in each group
# Out:
#       State_Code  County_Code  Census_Tract_Number    NUM_ALL    NUM_FHA  \
# USPS
# AK           2.0    98.357616             9.449338  49.079470  12.251656
# AL           1.0    75.836331          1889.544523  32.163669   8.333633
# AR           5.0    78.663690          3196.877113  37.946429   8.427083
# AZ           4.0    14.893676          2446.197818  52.276581  15.538568
# CA           6.0    54.777636          2005.292730  39.154278  11.303073
#
#       PCT_NUM_FHA       AMT_ALL      AMT_FHA  PCT_AMT_FHA  LOG_AMT_ALL  \
# USPS
# AK      27.172880  12450.741722  2905.072848    27.456326     8.791516
# AL      28.754330   5189.795863  1112.598022    29.368947     7.607937
# AR      21.377452   5377.254464  1105.171131    22.321766     7.848935
# AZ      33.198714   9571.252259  2425.145935    34.168339     8.423604
# CA      29.568614  12726.953972  2882.465766    32.965875     8.887090
#
#              ALAND        AWATER   ALAND_SQMI  AWATER_SQMI   INTPTLAT  \
# USPS
# AK    4.658549e+09  9.506639e+08  1798.675881   367.053397  61.124912
# AL    1.132807e+08  2.623693e+06    43.737926     1.013006  32.961141
# AR    1.981421e+08  4.362258e+06    76.503085     1.684271  35.078429
# AZ    1.443226e+08  6.508373e+05    55.723284     0.251290  33.315336
# CA    4.902491e+07  8.379937e+05    18.928632     0.323551  35.504532
#
#       INTPTLONG
# USPS
# AK                                          -148.239871
# AL                                           -86.761186
# AR                                           -92.548487
# AZ                                          -111.890482
# CA                                          -119.414014

# %%
df_by_state = df_joined.groupby('USPS').sum()

# %%
df_by_state
# Out:
#       State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# USPS
# AK         302.0      14852.0         1.426850e+03     7411     1850
# AL        1112.0      84330.0         2.101174e+06    35766     9267
# AR        3360.0      52862.0         2.148301e+06    25500     5663
# AZ        5756.0      21432.0         3.520079e+06    75226    22360
# CA       47058.0     429621.0         1.572751e+07   307087    88650
# CO        9808.0      57225.0         1.409516e+06    73352    17932
# CT        7263.0       4441.0         2.827371e+06    26614     7069
# DC        1881.0        171.0         1.022661e+04     6605     1154
# DE        2130.0        683.0         5.469877e+04     9105     2273
# FL       48864.0     292224.0         2.845053e+06   157431    44511
# GA       24687.0     252843.0         4.180310e+06    74926    24560
# HI        4395.0       1069.0         9.303038e+04     9008      571
# IA       15599.0      89823.0         2.254741e+06    31039     5169
# ID        4720.0       9761.0         1.372990e+06    16825     4057
# IL       51510.0     235744.0         1.669502e+07    96509    23294
# IN       26154.0     129069.0         4.468896e+06    57115    17237
# KS       14860.0      89129.0         2.111452e+06    25846     5758
# KY       22575.0     119041.0         4.400820e+06    33250     7900
# LA       24068.0      66122.0         2.034164e+06    34649     8721
# MA       36050.0      24028.0         6.263054e+06    61476     9532
# MD       32592.0     119081.0         7.515518e+06    51257    16089
# ME        8027.0       5005.0         1.307784e+06    10294     1882
# MI       62920.0     250568.0         7.187590e+06    73666    23093
# MN       35802.0     104828.0         2.825078e+06    56792    15318
# MO       39266.0     195070.0         4.494103e+06    54234    13248
# MS       17696.0      48000.0         3.004975e+06    16130     3822
# MT        7770.0      14541.0         3.475283e+05     8522     1548
# NC       79217.0     219519.0         5.465694e+06    80687    14336
# ND        7562.0      10167.0         1.095456e+06     9095     2183
# NE       16089.0      45329.0         2.200781e+06    18216     4802
# NH        9636.0       3354.0         8.784005e+05    11675     3006
# NJ       66538.0      37441.0         4.451743e+06    58911    14045
# NM       16275.0      10603.0         9.300229e+05    14446     4590
# NV       20992.0      12111.0         4.703753e+05    31456    11444
# NY      165780.0     288479.0         5.743982e+06   101335    25019
# OH      107796.0     220900.0         7.201164e+06    85510    25234
# OK       40960.0      95922.0         2.441192e+06    35878    11175
# OR       33702.0      32734.0         1.533094e+06    35891     7945
# PA      132216.0     193912.0         7.744383e+06    94954    25989
# PR       62208.0      67616.0         2.865860e+06    14053     5599
# RI       10428.0       1457.0         4.856397e+04     7567     2378
# SC       48150.0      52210.0         2.027367e+06    41531     9087
# SD        9706.0      15603.0         1.197368e+06     8474     1642
# TN       67586.0     145192.0         3.529262e+06    56973    15097
# TX      241584.0    1147425.0         1.328567e+07   243977    73549
# UT       28469.0      21015.0         1.099604e+06    36410    12502
# VA       94146.0     543493.0         4.895165e+06    85169    20495
# VT        9100.0       2728.0         1.309303e+06     4777      421
# WA       76055.0      60321.0         2.525773e+06    68902    15019
# WI       75295.0     104154.0         3.317837e+06    47913     7104
# WV       26136.0      25338.0         1.778945e+06    11739     2129
# WY        7224.0       2793.0         6.745105e+05     6644     1418
#
#         PCT_NUM_FHA   AMT_ALL   AMT_FHA    PCT_AMT_FHA   LOG_AMT_ALL  \
# USPS
# AK      4103.104850   1880062    438666    4145.905240   1327.518869
# AL     31974.815004   5771053   1237209   32658.268592   8460.025592
# AR     14365.648010   3613515    742675   15000.226620   5274.484550
# AZ     47772.949503  13773032   3489785   49168.239137  12121.565759
# CA    231906.640878  99817500  22607179  258551.356138  69701.447169
# CO     32680.189591  17390580   3463221   33993.259906  11046.585945
# CT     26040.081220   7665951   1429631   27520.712548   6909.699479
# DC      4579.199796   2751323    403218    4777.827561   1558.892032
# DE      6587.555864   1997634    423161    6956.076738   1840.216205
# FL    131126.352219  30754332   6866263  134137.105306  32938.490424
# GA     62631.951450  13244316   3338730   61289.720628  15072.024009
# HI      2123.015280   3564599    208685    2213.854620   2622.429689
# IA     15373.377156   4130606    637241   16151.012738   6446.981404
# ID      7070.159740   2630192    549405    7025.195000   2520.421328
# IL     87167.749937  18528555   3557118   93165.302415  24068.192973
# IN     45239.095490   8139337   2105828   45737.427636  11391.986112
# KS     17621.353238   3979198    745377   18616.693775   5747.787645
# KY     23249.102490   4853232   1049283   24100.309960   8282.319081
# LA     29163.061670   6109014   1357650   29733.875770   8509.016554
# MA     27782.508654  18417837   2285915   30539.970822  12956.684824
# MD     49487.224570  14432158   3815913   50318.834036  11771.044021
# ME      6383.032620   1899072    309540    6472.002467   2823.221931
# MI     82389.769781  10649440   2697808   83098.560401  18641.908169
# MN     34020.387210  10259406   2399666   34636.096634  11245.925133
# MO     33151.939946   8002476   1692613   34688.020889  10783.033139
# MS     14261.896620   2331314    518653   15094.597440   4654.838020
# MT      4758.048580   1600554    254623    4722.889209   2108.307733
# NC     41166.054551  15267954   2142607   40786.968536  17500.838358
# ND      4703.851760   1559733    351523    4689.335840   1587.165273
# NE     12815.147480   2643307    622676   13317.273270   4058.392698
# NH      7534.307970   2424561    574885    7596.509744   2542.421542
# NJ     65366.106197  17125056   3343413   69361.376948  16558.482046
# NM     15117.761350   2577715    690885   15353.448341   3668.203678
# NV     23665.032650   5272289   1811716   25310.763910   5373.359149
# NY    135397.247540  30631391   5578590  143698.707311  37436.909802
# OH     95810.860020  12703604   3064521   97158.874311  21112.247905
# OK     32206.617450   5324407   1482812   33723.354290   7919.368778
# OR     18631.718950   7669041   1499385   18786.193228   7175.161045
# PA     98378.514788  17140876   3956081  101016.810863  25112.401196
# PR     36440.434550   1989726    734527   37671.432010   6105.288084
# RI      8740.563870   1620058    417196    9199.040170   2002.158891
# SC     26163.977611   7720877   1327640   25771.975778   8543.257423
# SD      4099.887530   1316044    224819    4172.492150   1677.241666
# TN     36310.747850   9721705   2241320   36859.535939  11628.910700
# TX    175000.372320  45870174  10789870  179065.734095  40455.949556
# UT     19413.407750   6976643   2204234   20794.280460   5228.454172
# VA     45519.182440  23048658   4713396   46582.061165  16232.967806
# VT      1738.821260    940893     77355    1744.257130   1486.283532
# WA     33769.050593  17267705   3201463   34514.086295  12843.908451
# WI     22031.121552   7500688    971178   22901.272090  11070.715412
# WV      9271.010760   1675079    282703    9584.306890   3636.782603
# WY      2547.593870   1313697    248573    2603.529903   1140.518452
#
#              ALAND        AWATER  ALAND_SQMI  AWATER_SQMI       INTPTLAT  \
# USPS
# AK    7.034409e+11  1.435503e+11  271600.058    55425.063    9229.861778
# AL    1.259681e+11  2.917546e+09   48636.574     1126.463   36652.788706
# AR    1.331515e+11  2.931437e+09   51410.073     1131.830   23572.704566
# AZ    2.076803e+11  9.365548e+08   80185.805      361.606   47940.768545
# CA    3.845024e+11  6.572385e+09  148457.258     2537.612  278462.046524
# CO    2.654154e+11  1.165150e+09  102477.457      449.864   48432.768026
# CT    1.250847e+10  5.956998e+08    4829.558      229.995   33493.373062
# DC    1.406643e+08  5.034488e+06      54.312        1.945    6653.386692
# DE    5.025701e+09  2.426754e+08    1940.438       93.692    8382.726242
# FL    1.314206e+11  1.311422e+10   50741.788     5063.422  113139.351341
# GA    1.446248e+11  3.791627e+09   55839.969     1463.963   63197.182166
# HI    1.612452e+10  9.636695e+08    6225.706      372.072    6195.044403
# IA    1.440242e+11  1.076131e+09   55608.033      415.485   34441.230357
# ID    2.128808e+11  2.394396e+09   82193.726      924.481   13063.614709
# IL    1.432935e+11  2.176102e+09   55325.926      840.185  124954.872874
# IN    9.261274e+10  9.714431e+08   35757.989      375.071   58326.021881
# KS    2.048151e+11  1.308389e+09   79079.550      505.176   28563.825542
# KY    9.768249e+10  2.254021e+09   37715.420      870.261   40660.045199
# LA    1.096927e+11  1.373512e+10   42352.594     5303.158   33566.708117
# MA    2.008144e+10  1.732239e+09    7753.498      668.811   60951.097042
# MD    2.488631e+10  2.987752e+09    9608.664     1153.574   53169.066341
# ME    7.986437e+10  7.650733e+09   30835.806     2953.959   15504.917285
# MI    1.452887e+11  1.190129e+10   56096.255     4595.122  103934.002739
# MN    2.043629e+11  1.174936e+10   78904.949     4536.454   60009.514979
# MO    1.759263e+11  2.485170e+09   67925.537      959.536   52086.054061
# MS    1.187020e+11  2.241027e+09   45831.090      865.264   20613.345815
# MT    3.548013e+11  3.648865e+09  136989.564     1408.834   12119.133263
# NC    1.248629e+11  6.785419e+09   48209.846     2619.857   76082.912577
# ND    1.720402e+11  4.299018e+09   66425.103     1659.858    9431.257243
# NE    1.889610e+11  1.334642e+09   72958.253      515.311   21374.613818
# NH    2.318185e+10  8.944155e+08    8950.560      345.335   12610.822738
# NJ    1.890507e+10  1.256576e+09    7299.297      485.151   79087.550594
# NM    2.708337e+11  6.665176e+08  104569.486      257.346   16104.088659
# NV    2.370276e+11  1.423569e+09   91516.888      549.644   24320.363862
# NY    1.204434e+11  5.656721e+09   46503.460     2184.083  191221.672549
# OH    1.054847e+11  2.329936e+09   40727.844      899.593  111904.741440
# OK    1.739335e+11  3.341812e+09   67156.116     1290.293   36461.365730
# OR    2.474680e+11  3.215539e+09   95547.940     1241.528   36779.583131
# PA    1.157566e+11  1.468067e+09   44693.843      566.819  127416.332442
# PR    8.829924e+09  6.879412e+08    3409.260      265.605   15797.152852
# RI    2.669612e+09  3.311622e+08    1030.739      127.865    9895.575927
# SC    7.609522e+10  2.920504e+09   29380.527     1127.604   36399.423941
# SD    1.746153e+11  3.170402e+09   67419.341     1224.092    9301.244883
# TN    1.049839e+11  2.293528e+09   40534.518      885.529   51519.278368
# TX    6.518961e+11  1.416095e+10  251698.524     5467.578  156128.381067
# UT    2.075716e+11  6.919555e+09   80143.855     2671.655   23493.959221
# VA    1.018544e+11  4.499377e+09   39326.196     1737.214   69750.877112
# VT    2.386749e+10  1.034339e+09    9215.295      399.366    8013.192295
# WA    1.711495e+11  9.474026e+09   66081.203     3657.953   67911.362121
# WI    1.401892e+11  8.509759e+09   54127.361     3285.636   59885.350451
# WV    6.226658e+10  4.894455e+08   24041.264      188.978   18780.862461
# WY    2.514528e+11  1.862544e+09   97086.470      719.139    5504.476940
#
#       INTPTLONG
# USPS
# AK                                        -22384.220548
# AL                                        -96478.438935
# AR                                        -62192.582955
# AZ                                       -161010.403530
# CA                                       -936564.108106
# CO                                       -128951.982144
# CT                                        -58807.247931
# DC                                        -13168.526027
# DE                                        -16087.789976
# FL                                       -332655.086780
# GA                                       -159191.688320
# HI                                        -46154.061890
# IA                                        -76445.945549
# ID                                        -33939.970897
# IL                                       -267827.246583
# IN                                       -125309.424084
# KS                                        -71737.090203
# KY                                        -91615.930650
# LA                                        -99984.525487
# MA                                       -102905.318964
# MD                                       -104295.181493
# ME                                        -24296.802313
# MI                                       -203866.090831
# MN                                       -124150.551708
# MO                                       -124923.296838
# MS                                        -56629.424809
# MT                                        -28730.007701
# NC                                       -170681.697844
# ND                                        -19790.833488
# NE                                        -50542.369593
# NH                                        -20865.569391
# NJ                                       -145674.076826
# NM                                        -49410.323958
# NV                                        -76254.631695
# NY                                       -343856.056861
# OH                                       -228661.758653
# OK                                        -99200.235765
# OR                                       -100738.014356
# PA                                       -242852.399244
# PR                                        -57319.430347
# RI                                        -16932.765379
# SC                                        -86674.754107
# SD                                        -20859.318798
# TN                                       -124149.443019
# TX                                       -490564.133622
# UT                                        -65006.841668
# VA                                       -143608.120106
# VT                                        -13244.209002
# WA                                       -174531.160542
# WI                                       -121833.117630
# WV                                        -39110.042522
# WY                                        -13801.565936

# %%
# This is the analog of
# SELECT USPS, SUM(AMT_FHA), SUM(AMT_ALL), ... FROM df GROUP BY USPS;
df_by_state = usps_groups['AMT_FHA', 'AMT_ALL', 'NUM_FHA', 'NUM_ALL'].sum()
df_by_state.head()
# Out:
#        AMT_FHA   AMT_ALL  NUM_FHA  NUM_ALL
# USPS
# AK      438666   1880062     1850     7411
# AL     1237209   5771053     9267    35766
# AR      742675   3613515     5663    25500
# AZ     3489785  13773032    22360    75226
# CA    22607179  99817500    88650   307087

# %%
df_by_state['PCT_AMT_FHA'] = 100.0 * df_by_state['AMT_FHA']  / df_by_state['AMT_ALL']

# This sure looks different than the census-tract level histogram!
df_by_state['PCT_AMT_FHA'].hist(bins=20)

# %% [markdown]
# You can also specify a specific aggregation function per column:

# %%
usps_groups['NUM_FHA', 'NUM_ALL'].agg({'NUM_FHA': np.sum, 'NUM_ALL': np.mean}).head()
# Out:
#       NUM_FHA    NUM_ALL
# USPS
# AK       1850  49.079470
# AL       9267  32.163669
# AR       5663  37.946429
# AZ      22360  52.276581
# CA      88650  39.154278

# %% [markdown]
# The groupby function is especially useful when you define your own aggregation functions. Here, we define a function that returns the row for the census track located farthest to the north. The apply function attempts to 'combine results together in an intelligent way.' The list of Series objects from each call to `farthest_north` for each USPS code is collapsed into a single DataFrame table.

# %%
def farthest_north(state_df):
    # descending sort, then select row 0
    # the datatype will be a pandas Series
    return state_df.sort_values('INTPTLAT', ascending=False).iloc[0]

df_joined.groupby('USPS').apply(farthest_north)[:10]
# Out:
#       State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# USPS
# AK           2.0        185.0                 1.00       11        8
# AL           1.0         71.0              9502.00       10        2
# AR           5.0          7.0               208.03       91        9
# AZ           4.0          5.0                21.00       38       10
# CA           6.0         93.0                 4.00        2        0
# CO           8.0         75.0              9659.00        5        0
# CT           9.0          3.0              5243.00       46       16
# DC          11.0          1.0                16.00       41       10
# DE          10.0          3.0               112.02       23        9
# FL          12.0         33.0                40.00        4        0
#
#       PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA         GEOID  LOG_AMT_ALL  \
# USPS
# AK       72.72730     1958     1604     81.92030  2.185000e+09     7.580189
# AL       20.00000      700      216     30.85710  1.071950e+09     6.552508
# AR        9.89011     9673      909      9.39729  5.007021e+09     9.177197
# AZ       26.31580     7078     1831     25.86890  4.005002e+09     8.864888
# CA        0.00000      741        0      0.00000  6.093000e+09     6.609349
# CO        0.00000      388        0      0.00000  8.075966e+09     5.963579
# CT       34.78260     6441     2580     40.05590  9.003524e+09     8.770594
# DC       24.39020    23623     6368     26.95680  1.100100e+10    10.070018
# DE       39.13040     5656     2370     41.90240  1.000301e+10     8.640649
# FL        0.00000      192        0      0.00000  1.203300e+10     5.262690
#
#      USPS         ALAND       AWATER  ALAND_SQMI  AWATER_SQMI   INTPTLAT  \
# USPS
# AK     AK  2.532416e+08  378198536.0      97.777      146.023  71.287938
# AL     AL  9.275512e+07    2986584.0      35.813        1.153  34.965286
# AR     AR  1.397141e+07     295088.0       5.394        0.114  36.486278
# AZ     AZ  5.956008e+07    4650137.0      22.996        1.795  36.916588
# CA     CA  5.329775e+08    3118247.0     205.784        1.204  41.946648
# CO     CO  1.425537e+09    3036714.0     550.403        1.172  40.924098
# CT     CT  1.314194e+07     242922.0       5.074        0.094  42.024605
# DC     DC  2.650934e+06      35617.0       1.024        0.014  38.984972
# DE     DE  3.704573e+06          0.0       1.430        0.000  39.832216
# FL     FL  9.382286e+07    4475275.0      36.225        1.728  30.967491
#
#       INTPTLONG
# USPS
# AK                                          -156.685618
# AL                                           -85.777448
# AR                                           -94.283383
# AZ                                          -111.470183
# CA                                          -122.634808
# CO                                          -103.073557
# CT                                           -72.530403
# DC                                           -77.038232
# DE                                           -75.521217
# FL                                           -87.277931

# %% [markdown]
# ## Sorting by indices and columns
#
# We can sort by the row (or column) index.

# %%
df_by_state.sort_index(ascending=False).head()
# Out:
#       AMT_FHA   AMT_ALL  NUM_FHA  NUM_ALL  PCT_AMT_FHA
# USPS
# WY     248573   1313697     1418     6644    18.921639
# WV     282703   1675079     2129    11739    16.876995
# WI     971178   7500688     7104    47913    12.947852
# WA    3201463  17267705    15019    68902    18.540177
# VT      77355    940893      421     4777     8.221445

# %% [markdown]
# We can also sort by the value in a column

# %%
df_by_state.sort_values('AMT_FHA', ascending=False).head()
# Out:
#        AMT_FHA   AMT_ALL  NUM_FHA  NUM_ALL  PCT_AMT_FHA
# USPS
# CA    22607179  99817500    88650   307087    22.648513
# TX    10789870  45870174    73549   243977    23.522627
# FL     6866263  30754332    44511   157431    22.326165
# NY     5578590  30631391    25019   101335    18.212003
# VA     4713396  23048658    20495    85169    20.449763

# %% [markdown]
# ## Unique values
#
# As in SQL, pandas can compute unique values, value counts, and test for membership

# %%
df['State_Code'].unique()[:10]
# Out:
# array([  8.,  28.,  40.,  39.,  12.,  36.,  48.,  13.,  17.,  34.])

# %%
df['State_Code'].value_counts().head()
# Out:
# 6.0     7872
# 48.0    5092
# 36.0    4629
# 12.0    4099
# 42.0    3184
# Name: State_Code, dtype: int64

# %%
df[df['State_Code'].isin(df['State_Code'].head(3))]
# Out:
#        State_Code  County_Code  Census_Tract_Number  NUM_ALL  NUM_FHA  \
# 0             8.0         75.0                  NaN        1        1
# 1            28.0         49.0               103.01        1        1
# 2            40.0          3.0                  NaN        1        1
# 95           28.0         77.0                  NaN        1        1
# 139          40.0        127.0               978.00        1        1
# 205          28.0         63.0              9502.00        1        1
# 325          40.0        109.0              1076.06        1        1
# 382           8.0         31.0                 8.00        1        1
# 423          40.0        143.0                30.00        5        5
# 458          40.0        109.0              1041.00        2        2
# 461           8.0         41.0                44.02        1        1
# 479           8.0        123.0                 6.00        1        1
# 574           8.0         43.0                  NaN        1        1
# 603          28.0         49.0                25.00        1        1
# 651          40.0        143.0                 2.00        1        1
# 727          40.0         31.0                24.01        1        1
# 772          28.0        151.0                12.00        3        3
# 911          28.0        151.0                21.00        2        2
# 958           8.0          1.0                92.03        1        1
# 1028          8.0          5.0                49.52        1        1
# 1045         40.0        109.0              1055.00        1        1
# 1060         40.0        143.0                49.00        6        6
# 1067         40.0        143.0                90.08        1        1
# 1088         40.0         25.0              9503.00        3        3
# 1112         28.0         49.0                22.00        1        1
# 1131         28.0        103.0              9502.00        1        1
# 1169         28.0         49.0                27.00        1        1
# 1279          8.0          1.0                86.03       11        9
# 1373          8.0         31.0                83.05       28       25
# 1415         40.0        109.0              1073.05        3        2
# ...           ...          ...                  ...      ...      ...
# 71326        28.0         35.0                 6.00        3        0
# 71334        40.0        109.0              1030.00        3        0
# 71357        28.0         49.0                36.00        4        0
# 71387        40.0        109.0              1025.00        2        0
# 71402         8.0        107.0                  NaN        2        0
# 71404        28.0         49.0                37.00        2        0
# 71405         8.0         89.0              9685.00       11        0
# 71417         8.0         31.0                40.06       78        0
# 71419        40.0         63.0              4847.00        6        0
# 71445        40.0        141.0               701.00        3        0
# 71464        40.0         15.0              1618.00        3        0
# 71518        40.0         91.0              7799.00        7        0
# 71521        40.0         89.0               982.00        3        0
# 71528        40.0         31.0                19.02        3        0
# 71569        28.0          7.0               601.00        2        0
# 71623        28.0         87.0                10.00       21        0
# 71651        28.0        133.0              9501.00        4        0
# 71657        40.0         23.0              9673.00        3        0
# 71698        40.0         87.0              4004.00        4        0
# 71745        40.0        137.0                  NaN        2        0
# 71754         8.0         31.0                39.01      101        0
# 71762        40.0        121.0              4863.00        1        0
# 71828         8.0          5.0                56.22       30        0
# 71873        40.0        109.0              1079.00        1        0
# 71874        28.0         93.0              9504.02       11        0
# 71875        28.0         89.0               307.00        1        0
# 71883         8.0        105.0              9768.00        2        0
# 71958        28.0         49.0                16.00        3        0
# 71974        28.0        123.0               206.00        8        0
# 71994        40.0        143.0                  NaN        3        0
#
#        PCT_NUM_FHA  AMT_ALL  AMT_FHA  PCT_AMT_FHA         GEOID  LOG_AMT_ALL
# 0         100.0000      258      258     100.0000           NaN     5.556828
# 1         100.0000       71       71     100.0000  2.804901e+10     4.276666
# 2         100.0000      215      215     100.0000           NaN     5.375278
# 95        100.0000      177      177     100.0000           NaN     5.181784
# 139       100.0000      119      119     100.0000  4.012710e+10     4.787492
# 205       100.0000      133      133     100.0000  2.806395e+10     4.897840
# 325       100.0000       82       82     100.0000  4.010911e+10     4.418841
# 382       100.0000      107      107     100.0000  8.031001e+09     4.682131
# 423       100.0000      243      243     100.0000  4.014300e+10     5.497168
# 458       100.0000       93       93     100.0000  4.010910e+10     4.543295
# 461       100.0000       87       87     100.0000  8.041004e+09     4.477337
# 479       100.0000       54       54     100.0000  8.123001e+09     4.007333
# 574       100.0000      149      149     100.0000           NaN     5.010635
# 603       100.0000       82       82     100.0000  2.804900e+10     4.418841
# 651       100.0000       74       74     100.0000  4.014300e+10     4.317488
# 727       100.0000       86       86     100.0000  4.003100e+10     4.465908
# 772       100.0000      118      118     100.0000  2.815100e+10     4.779123
# 911       100.0000      107      107     100.0000  2.815100e+10     4.682131
# 958       100.0000      212      212     100.0000  8.001009e+09     5.361292
# 1028      100.0000      177      177     100.0000  8.005005e+09     5.181784
# 1045      100.0000       32       32     100.0000  4.010911e+10     3.496508
# 1060      100.0000      490      490     100.0000  4.014300e+10     6.196444
# 1067      100.0000      179      179     100.0000  4.014301e+10     5.192957
# 1088      100.0000      178      178     100.0000  4.002595e+10     5.187386
# 1112      100.0000       39       39     100.0000  2.804900e+10     3.688879
# 1131      100.0000      165      165     100.0000  2.810395e+10     5.111988
# 1169      100.0000       78       78     100.0000  2.804900e+10     4.369448
# 1279       81.8182     1186     1148      96.7960  8.001009e+09     7.079184
# 1373       89.2857     3353     3134      93.4685  8.031008e+09     8.117909
# 1415       66.6667      252      233      92.4603  4.010911e+10     5.533389
# ...            ...      ...      ...          ...           ...          ...
# 71326       0.0000      119        0       0.0000  2.803500e+10     4.787492
# 71334       0.0000     2370        0       0.0000  4.010910e+10     7.771067
# 71357       0.0000      140        0       0.0000  2.804900e+10     4.948760
# 71387       0.0000      316        0       0.0000  4.010910e+10     5.758902
# 71402       0.0000      475        0       0.0000           NaN     6.165418
# 71404       0.0000       94        0       0.0000  2.804900e+10     4.553877
# 71405       0.0000     1084        0       0.0000  8.089968e+09     6.989335
# 71417       0.0000    40316        0       0.0000  8.031004e+09    10.604528
# 71419       0.0000      870        0       0.0000  4.006348e+10     6.769642
# 71445       0.0000      249        0       0.0000  4.014107e+10     5.521461
# 71464       0.0000      243        0       0.0000  4.001516e+10     5.497168
# 71518       0.0000     1245        0       0.0000  4.009178e+10     7.127694
# 71521       0.0000      348        0       0.0000  4.008910e+10     5.855072
# 71528       0.0000       97        0       0.0000  4.003100e+10     4.584967
# 71569       0.0000      129        0       0.0000  2.800706e+10     4.867534
# 71623       0.0000     4572        0       0.0000  2.808700e+10     8.427925
# 71651       0.0000      134        0       0.0000  2.813395e+10     4.905275
# 71657       0.0000      199        0       0.0000  4.002397e+10     5.298317
# 71698       0.0000     1157        0       0.0000  4.008740e+10     7.054450
# 71745       0.0000      171        0       0.0000           NaN     5.147494
# 71754       0.0000    42838        0       0.0000  8.031004e+09    10.665204
# 71762       0.0000       99        0       0.0000  4.012149e+10     4.605170
# 71828       0.0000    15439        0       0.0000  8.005006e+09     9.644717
# 71873       0.0000       35        0       0.0000  4.010911e+10     3.583519
# 71874       0.0000      517        0       0.0000  2.809395e+10     6.249975
# 71875       0.0000       24        0       0.0000  2.808903e+10     3.218876
# 71883       0.0000      176        0       0.0000  8.105977e+09     5.176150
# 71958       0.0000      321        0       0.0000  2.804900e+10     5.774552
# 71974       0.0000      854        0       0.0000  2.812302e+10     6.751101
# 71994       0.0000      372        0       0.0000           NaN     5.921578
#
# [2939 rows x 11 columns]

# %% [markdown]
# ## Handling missing and NA data
#
#
# When you read in a CSV file / SQL database there are often "NA" (or "null", "None", etc.) values.  The CSV reader has a special field for specifying how this is denoted, and SQL has the built-in notion of NULL.  Pandas provides some tools for working with these -- they are generally similar to (and a little bit worse than) `R`.
#
# Note that these methods are by default not in place -- that is, they create a new series and do not change the original one.
#
# For more details: http://pandas.pydata.org/pandas-docs/stable/missing_data.html

# %%
df['GEOID'][:10]
# Out:
# 0             NaN
# 1    2.804901e+10
# 2             NaN
# 3    3.911306e+10
# 4    1.210501e+10
# 5    1.208698e+10
# 6    3.903512e+10
# 7    1.210302e+10
# 8    3.611900e+10
# 9             NaN
# Name: GEOID, dtype: float64

# %% [markdown]
# `.isnull()` and `.notnull()` test for null-ness and return a Boolean series.

# %%
df['GEOID'].isnull()[:10]
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9     True
# Name: GEOID, dtype: bool

# %% [markdown]
# `.dropna()` removes the rows with null data

# %%
df['GEOID'].size, df['GEOID'].dropna().size
# Out:
# (72035, 71040)

# %% [markdown]
# `.fillna()` replaces N/A values with another value.  `.interpolate()` replaces null values by (linear, or quadratic, or...) interpolation.  There is support for indexing by times (not necessarily equally spaced), etc. in the documentation.

# %%
df['fill_0'] = df['GEOID'].fillna(0)                          # Fills constant value, here 0
df['fill_forward'] = df['GEOID'].fillna(method='ffill')       # Fill forwards
df['fill_back'] = df['GEOID'].fillna(method='bfill', limit=5) # Fill backwards, at most 5
df['fill_mean'] = df['GEOID'].fillna(df['GEOID'].mean())      # Fills constant value, here the mean (imputation)
df['fill_interp'] = df['GEOID'].interpolate()                 # Fills interpolated value
df[['GEOID', 'fill_0', 'fill_forward', 'fill_back', 'fill_mean', 'fill_interp']][:10]
# Out:
#           GEOID        fill_0  fill_forward     fill_back     fill_mean  \
# 0           NaN  0.000000e+00           NaN  2.804901e+10  2.837319e+10
# 1  2.804901e+10  2.804901e+10  2.804901e+10  2.804901e+10  2.804901e+10
# 2           NaN  0.000000e+00  2.804901e+10  3.911306e+10  2.837319e+10
# 3  3.911306e+10  3.911306e+10  3.911306e+10  3.911306e+10  3.911306e+10
# 4  1.210501e+10  1.210501e+10  1.210501e+10  1.210501e+10  1.210501e+10
# 5  1.208698e+10  1.208698e+10  1.208698e+10  1.208698e+10  1.208698e+10
# 6  3.903512e+10  3.903512e+10  3.903512e+10  3.903512e+10  3.903512e+10
# 7  1.210302e+10  1.210302e+10  1.210302e+10  1.210302e+10  1.210302e+10
# 8  3.611900e+10  3.611900e+10  3.611900e+10  3.611900e+10  3.611900e+10
# 9           NaN  0.000000e+00  3.611900e+10  4.811301e+10  2.837319e+10
#
#     fill_interp
# 0           NaN
# 1  2.804901e+10
# 2  3.358104e+10
# 3  3.911306e+10
# 4  1.210501e+10
# 5  1.208698e+10
# 6  3.903512e+10
# 7  1.210302e+10
# 8  3.611900e+10
# 9  4.211601e+10

# %% [markdown]
# ### Note
# N/A values are (usually) smartly ignored when performing other calculations on dataframes. For example, when using string methods on series:

# %%
text_series = df['GEOID'].replace(0, np.nan).apply(str)
print(text_series[:10])

# %%
text_series[:10].str.split('.')

# %% [markdown]
# Applying mean on numeric data ignores NA's by default (check docs):

# %%
df['GEOID'].mean()

# %% [markdown]
# ## Manipulating strings
#
# Element-wise string operations are available through the `.str` attribute.

# %%
states = df_joined['USPS'].dropna()
states[states.str.contains('A')].head()

# %% [markdown]
# ## Indices in Pandas
#
# Pandas indices allow us to handle data naturally.  **Elements are associated based on their index, not their order.**

# %%
s1 = pd.Series([1,2,3], index=['a', 'b', 'c'])
s2 = pd.Series([3,2,1], index=['c', 'b', 'a'])
s1 + s2

# %%
s3 = pd.Series([3,2,1], index=['c', 'd', 'e'])
s1 + s3

# %% [markdown]
# Missing values get a NaN, but this can be replaced by a fill value of your choice.

# %%
s1.add(s3, fill_value=0)

# %% [markdown]
# ## Function application and mapping
#
# For element-wise function application, the most straightforward thing to do is to apply numpy functions to these objects:

# %%
df1 = pd.DataFrame(np.arange(24).reshape(4,6))

np.sin(df1)

# %% [markdown]
# This relies on numpy functions automatically broadcasting themselves to work element-wise.  To apply a pure-python function to each element, use the `.applymap()` method.

# %%
df1.applymap(lambda x: "%.2f" % x)

# %% [markdown]
# However, sometimes you want to compute things column-wise or row-wise.  In this case, you will need to use the `apply` method.
#
# For example, the following takes the range of each column.

# %%
df1.apply(lambda x: x.max() - x.min())

# %% [markdown]
# And this takes the range of reach row.

# %%
df1.apply(lambda x: x.max() - x.min(), axis=1)

# %% [markdown]
# ### Pandas HTML data import example
#
# Pandas takes a "batteries included" approach and throws in a whole lot of convenience functions.  For instance it has import functions for a variety of formats.  One of the pleasant surprises is a command `read_html` that's meant to automate the process of extracting tabular data from HTML.  In particular, it works pretty well with tables on Wikipedia.
#
# Let's do an example: We'll try to extract the list of the world's tallest structures from
# http://en.wikipedia.org/wiki/List_of_tallest_buildings_and_structures_in_the_world.

# %%
dfs = pd.read_html('http://en.wikipedia.org/wiki/List_of_tallest_buildings_and_structures_in_the_world', header=0, parse_dates=False)

# There are several tables on the page.  By inspection we can figure out which one we want
tallest = dfs[3]
print(tallest.columns)
# The coordinates column needs to be fixed up.  This is a bit of string parsing:
def clean_lat_long(s):
    try:
        parts = s.split("/")
    except AttributeError:
        return (None, None)
    if len(parts) < 3:
        return (None, None)
    m = re.search(r"(\d+[.]\d+);[^\d]*(\d+[.]\d+)[^\d]", parts[2])
    if not m:
        return (None, None)
    return (m.group(1), m.group(2))

tallest['Clean_Coordinates'] = tallest['Coordinates'].apply(clean_lat_long)
tallest['Latitude'] = tallest['Clean_Coordinates'].apply(lambda x:x[0])
tallest['Longitude'] = tallest['Clean_Coordinates'].apply(lambda x:x[1])

# Et voila
tallest.head()

# %% [markdown]
# **Exercise**
#
# 1. Parse the table rankings of [UK universities available on Wikipedia](https://en.wikipedia.org/wiki/Rankings_of_universities_in_the_United_Kingdom):

# %% [markdown]
# ## Pandas Timestamps
#
# Pandas comes with excellent tools for managing temporal data. Central to this is the Timestamp class, which can infer timestamps from many sensible inputs:

# %%
print(pd.Timestamp('July 4, 2016'))
print(pd.Timestamp('Monday, July 4, 2016'))
print(pd.Timestamp('Tuesday, July 4th, 2016'))  # notice it ignored 'Tuesday'
print(pd.Timestamp('Monday, July 4th, 2016 05:00 PM'))
print(pd.Timestamp('04/07/2016T17:20:13.123456'))
print(pd.Timestamp(1467651600000000000))  # number of ns since the epoch, 1/1/1970

# %% [markdown]
# It can manage timestamps with timezones:

# %%
july4 = pd.Timestamp('Monday, July 4th, 2016 05:00 PM').tz_localize('US/Eastern')
labor_day = pd.Timestamp('9/5/2016 12:00', tz='US/Eastern')
thanksgiving = pd.Timestamp('11/24/2016 16:00')  # no timezone

# %% [markdown]
# Pandas can do calculations on Timestamps if they are both localized to the same timezone or neither has a timezone.

# %%
print(labor_day - july4)
# print thanksgiving - july4  # generates an error

# %% [markdown]
# The time series offsets are useful for calculating dates relative to another date. Observe it skips over weekend days but is oblivious to holidays. Pandas does support [Custom Calendars](http://pandas.pydata.org/pandas-docs/stable/timeseries.html#holidays-holiday-calendars) if you need them.

# %%
from pandas.tseries.offsets import BDay, Day, BMonthEnd

print(july4 + Day(5))  # 5 calendar days later, a Saturday.
print(july4 + BDay(5))  # 5 business days later, or the following Monday.
print(july4 - BDay(1))  # 1 business day earlier, or the previous Friday.
print(july4 + BMonthEnd(1))  # last business day of the month.

# %% [markdown]
# Pandas can generate a range of dates. Here, we generate a list of business days in January of 2016:

# %%
business_days = pd.date_range('1/1/2016', '1/31/2016', freq='B')
business_days

# %% [markdown]
# This can in turn be used in as a DataFrame index:

# %%
time_df = pd.DataFrame(np.random.rand(len(business_days)),
                    index=business_days,
                   columns=['random'])
time_df.head()

# %% [markdown]
# The same timezone functions are still available.

# %%
time_df.tz_localize('UTC').tz_convert('US/Pacific').head()

# %% [markdown]
# ## Multi-indices, stacking, and pivot tables
#
# Data frames can contain multiple indices for rows or columns.  For example, grouping by two columns will produce a two-level row index.

# %%
grouped = df.groupby(['State_Code', 'County_Code'])[['NUM_ALL', 'NUM_FHA']].sum()
grouped.head()

# %% [markdown]
# A row index can be converted into a column index with the `.unstack()` method:

# %%
grouped.unstack().head()

# %% [markdown]
# And the `.stack()` method does the opposite:

# %%
np.all(grouped.unstack().stack() == grouped)

# %% [markdown]
# This can be done with one step with the `pivot_table()` function.

# %%
pd.pivot_table(df, index='State_Code', columns='County_Code',
               values=['NUM_ALL', 'NUM_FHA'], aggfunc=np.sum).head()

# %% [markdown]
# You may already by familiar with pivot tables in Excel.  These work similarly, and area  good tool for changing the dependent and independent variables for aggregations of data. See http://pandas.pydata.org/pandas-docs/stable/reshaping.html for more information.

# %% [markdown]
# ## Plugging into more advanced analytics
#
# Almost any "advanced analytics" tool in the Python ecosystem is going to take as input `np.array` type arrays.  You can access the underlying array of a data frame column as
#
#         df['column'].values
#
# Many of them take `nd.array` whose underlying data can be accessed by
#
#         df.values
#
# directly.  *Most* of the time, they will take `df['column']` and `df` without needing to look at values.
#
# This is particularly important if you want to use Pandas with the sklearn library. See this [blog post](http://www.markhneedham.com/blog/2013/11/09/python-making-scikit-learn-and-pandas-play-nice/) for an example.

# %% [markdown]
# ### Exit Tickets
# 1. Describe several situations where you would prefer to use Pandas, and several where you'd prefer SQL.
# 1. Write the syntax for slicing the rows of a dataframe according to a filtering criterion.
# 1. Write the syntax for selecting, adding, or removing columns of a dataframe.

# %%
### This will load the iris dataset.
### Perfom a Exploratory Data Analysis using pandas

from sklearn.datasets import load_iris

iris_data = load_iris()

print(iris_data.DESCR)

df= pd.DataFrame(iris_data.data, columns=iris_data.feature_names)
df['label'] = iris_data.target
