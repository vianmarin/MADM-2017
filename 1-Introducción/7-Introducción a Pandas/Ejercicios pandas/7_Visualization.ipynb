# %% [markdown]
# # Visualizing the Titanic Disaster

# %% [markdown]
# ### Introduction:
#
# This exercise is based on the titanic Disaster dataset avaiable at [Kaggle](https://www.kaggle.com/c/titanic).
# To know more about the variables check [here](https://www.kaggle.com/c/titanic/data)
#
# It is recomended also to use **seaborn** library
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# ### Step 2. Import the dataset from titanic.csv

# %% [markdown]
# ### Step 3. Assign it to a variable titanic

# %%
titanic = pd.read_csv('data/titanic.csv')

# %% [markdown]
# ### Step 4. Set PassengerId as the index

# %%
titanic = titanic.set_index('PassengerId')

# %% [markdown]
# ### Step 5. Create a pairplot to check how variables correlate

# %%
# %matplotlib inline
print(sb.pairplot(titanic.dropna()))
# Out:
# <seaborn.axisgrid.PairGrid object at 0x0000027CF8FD54E0>

# %% [markdown]
# ### Step 6. Create a scatterplot with the Fare payed and the Age, differ the plot color by gender

# %%
titanic['Sexc'] = titanic['Sex']
titanic['Sexc'][titanic['Sexc']=='male'] = 1
titanic['Sexc'][titanic['Sexc']=='female'] = 2
plt.scatter(titanic.Fare,titanic.Age, c=titanic.Sexc)
# Out:
# C:\Users\Victor\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Victor\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Step 7. How many people survived?

# %%
titanic['Survived'].sum()
# Out:
# 342

# %% [markdown]
# ### Step 8. Create a histogram with the Fare payed

# %%
plt.hist(titanic.Fare)
# Out:
# (array([ 732.,  106.,   31.,    2.,   11.,    6.,    0.,    0.,    0.,    3.]),
#  array([   0.     ,   51.23292,  102.46584,  153.69876,  204.93168,
#          256.1646 ,  307.39752,  358.63044,  409.86336,  461.09628,
#          512.3292 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### Step 9: Create a diagonal correlation plot af all variables ([tip](http://seaborn.pydata.org/examples/many_pairwise_correlations.html))

# %%
# Compute the correlation matrix
corr = titanic.corr()

# Máscara triangular superior para que no se dupliquen
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Tamaño figura
f, ax = plt.subplots(figsize=(11, 9))

# Colores
cmap = sb.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sb.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
